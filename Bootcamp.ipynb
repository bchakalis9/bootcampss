# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file = "/Users/billychakalis/Documents/AstroCOM_NYC/BootCamp/stars.txt"
# !ls /Users/billychakalis/Documents/AstroCOM_NYC/BootCamp/stars.txt
temp, mag = np.loadtxt(file, unpack = True)
mag.shape, temp.shape
# Out:
# /Users/billychakalis/Documents/AstroCOM_NYC/BootCamp/stars.txt
# ((7860,), (7860,))

# %%
fig, ax = plt.subplots(2,2)
ax[0][0].scatter(temp, mag)
ax[1][0].scatter(temp, mag)
ax[0][1].scatter(temp, mag)
ax[1][1].scatter(temp, mag)

# %%
fig, ax = plt.subplots(2,2)
ax[0][0].scatter(temp, mag, marker='.', c='blue')
ax[1][0].scatter(temp, mag, marker='s', c='cyan', s = 3)
ax[0][1].scatter(temp, mag, marker='o', s=5, c='orange')
ax[1][1].scatter(temp, mag, marker='x', s=1, c='magenta')

# %%
fig, ax = plt.subplots(2,2)
ax[0][0].scatter(temp, mag, marker='.', c='blue')
ax[1][0].scatter(temp, mag, marker='s', c='cyan', s = 3)
ax[0][1].scatter(temp, mag, marker='o', s=5, c='orange')
ax[1][1].scatter(temp, mag, marker='x', s=1, c='magenta')
plt.subplots_adjust(hspace=0, wspace=0)

# %%
fig, ax = plt.subplots(2,2, sharex = True, sharey = True, figsize=(6,6))
ax[0][0].scatter(temp, mag, marker='.', c='blue')
ax[1][0].scatter(temp, mag, marker='s', c='cyan', s = 3)
ax[0][1].scatter(temp, mag, marker='o', s=5, c='orange')
ax[1][1].scatter(temp, mag, marker='x', s=1, c='magenta')
plt.subplots_adjust(hspace=0, wspace=0)
ax[0][0].set_xlim([15000,0])
ax[0][0].set_ylim([18,-3])
# Out:
# (18.0, -3.0)

# %%
fig, ax = plt.subplots(2,2, sharex = True, sharey = True, figsize=(6,6))
ax[0][0].scatter(temp, mag, marker='.', c='blue')
ax[1][0].scatter(temp, mag, marker='s', c='cyan', s = 3)
ax[0][1].scatter(temp, mag, marker='o', s=5, c='orange')
ax[1][1].scatter(temp, mag, marker='x', s=1, c='magenta')
plt.subplots_adjust(hspace=0, wspace=0)
ax[0][0].set_xlim([14999,0])
ax[0][0].set_ylim([19,-3])
# Out:
# (19.0, -3.0)

# %%
fig, ax = plt.subplots(2,2, sharex = True, sharey = True, figsize=(6,6))
ax[0][0].scatter(temp, mag, marker='.', c='blue')
ax[1][0].scatter(temp, mag, marker='s', c='cyan', s = 3)
ax[0][1].scatter(temp, mag, marker='o', s=5, c='orange')
ax[1][1].scatter(temp, mag, marker='x', s=1, c='magenta')
plt.subplots_adjust(hspace=0, wspace=0)
ax[0][0].set_xlim([14999,0])
ax[0][0].set_ylim([19,-3])

ax[1][0].set_xlabel("Temperature")
ax[1][0].set_ylabel("Magnitude")
ax[1][1].set_xlabel("Temperature")
ax[0][0].set_ylabel("Magnitude")
# Out:
# Text(0, 0.5, 'Magnitude')

# %%
fig, ax = plt.subplots(2,2, sharex = True, sharey = True, figsize=(6,6))
axs = fig.add_subplot(111, frameon = False)
axs.tick_params(labelcolor = 'none', top = False, bottom = False, right = False, left = False)
axs.set_xlabel("Temperature", fontsize = 'x-large', labelpad = 10)
axs.set_ylabel("Magnitude", fontsize = 'x-large', labelpad = 20)

ax[0][0].scatter(temp, mag, marker='.', c='blue')
ax[1][0].scatter(temp, mag, marker='s', c='cyan', s = 3)
ax[0][1].scatter(temp, mag, marker='o', s=5, c='orange')
ax[1][1].scatter(temp, mag, marker='x', s=1, c='magenta')
plt.subplots_adjust(hspace=0, wspace=0)
ax[0][0].set_xlim([14999,0])
ax[0][0].set_ylim([19,-3])

#ax[1][0].set_xlabel("Temperature")
#ax[1][0].set_ylabel("Magnitude")
#ax[1][1].set_xlabel("Temperature")
#ax[0][0].set_ylabel("Magnitude")
# Out:
# (19.0, -3.0)

# %%
fig, ax = plt.subplots(2,2, sharex = True, sharey = True, figsize=(6,6))
axs = fig.add_subplot(111, frameon = False)
axs.tick_params(labelcolor = 'none', top = False, bottom = False, right = False, left = False)
axs.set_xlabel("Temperature", fontsize = 'x-large', labelpad = 10)
axs.set_ylabel("Magnitude", fontsize = 'x-large', labelpad = 20)
axs.set_title("Test Plot")

ax[0][0].scatter(temp, mag, marker='.', c='blue')
ax[1][0].scatter(temp, mag, marker='s', c='cyan', s = 3)
ax[0][1].scatter(temp, mag, marker='o', s=5, c='orange')
ax[1][1].scatter(temp, mag, marker='x', s=1, c='magenta')
plt.subplots_adjust(hspace=0, wspace=0)
ax[0][0].set_xlim([14999,0])
ax[0][0].set_ylim([19,-3])

ax[0][0].text(13500, 18, "Phase I", color = 'red', fontsize = 'large')
bb_props = dict(boxstyle = 'round', facecolor = 'lightgray', alpha = .5)
ax[0][1].text(13500, 8, "Phase II", rotation = 45, color = "darkblue", fontsize = 'small', bbox = bb_props)
ax[1][0].annotate("Phase III", xy = (0.05, 0.05), xycoords = "axes fraction", color = 'brown', fontsize = 'xx-large')
ax[1][1].annotate("Phase IV", xytext= (0.05, 0.05), xycoords = "axes fraction", xy = (0.35, 0.25), arrowprops = dict(arrowstyle='->', connectionstyle = 'arc3'))
# Out:
# Text(0.05, 0.05, 'Phase IV')
